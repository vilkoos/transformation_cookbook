# %% [markdown]
# # How to select rows and columns
#
# To answers your questions you typically do not need all the data that are present in the input file.
#
# This notebook shows
# - how to select the observed cases (i.e. rows).
# - how to select the variables (i.e. columns).
#
# We will demonstrate two ways to do that:
# - the prefered way that uses SQL
# (We will use [pandasql](http://blog.yhat.com/posts/pandasql-intro.html) because it can do sql directly on dataframes and returns a dataframe)
# - the alternative way that uses native pandas commands

# %% [markdown]
# # 0 - setup notebook

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
#-- install pandasql if necessary ----
#-- see: http://blog.yhat.com/posts/pandasql-intro.html ----
from pandasql import *

# %% [markdown]
# # 1 - get some data

# %%
cities = pd.read_excel('./dat/city.xlsx', sheetname='citydata')
print(cities.shape)
cities.head()
# Out:
# (69, 42)
#         city   areaC    areaM  popC  popM  fornB  growP   ppp  share  unempR  \
# 0     London   321.0   1584.0  8.20  9.01  0.370  0.009  52.0  0.032   0.083
# 1  Amsterdam   165.0    807.0  0.76  1.40  0.473  0.012  46.0  0.010   0.054
# 2     Ankara    31.0  25437.0  3.54  4.77    NaN  0.257  21.2    NaN   0.121
# 3     Athens    39.0    381.0  0.66  4.01  0.220    NaN  30.5    NaN   0.162
# 4    Bangkok  1569.0   7762.0  5.72  6.50  0.200  0.031  23.4  0.002   0.022
#
#     ...    lfExpF  nrMDs  nrHosp  asLegi  nrMus  nrArts  greens  airQ  effLaw  \
# 0   ...      83.3    NaN   255.0     1.0  237.0   307.0    0.14  29.0     1.0
# 1   ...      80.8  269.0     7.0     1.0   68.0   141.0    0.57  24.0     1.0
# 2   ...       NaN    NaN     7.0     1.0   36.0     NaN    0.07  46.0     0.0
# 3   ...       NaN    NaN    23.0     1.0   47.0     NaN     NaN  41.0     1.0
# 4   ...      74.0    NaN   173.0     NaN   27.0     NaN    0.24  54.0     1.0
#
#    retFit
# 0     1.0
# 1     0.0
# 2     0.0
# 3     NaN
# 4     1.0
#
# [5 rows x 42 columns]

# %% [markdown]
# The dataframe contains data for 69 of the largest cities in the world.
# The cities are described by 42 variables (see the appendix at the end of this notebook for a dictionary).
#
# We want to know if the number of hospitals is proportional to the number of people that live in the city.
# We are only interested in very large cities with more than 10 million inhabitants.
#
# In the appendix we can find that
# - the column city contains the city name
# - the column popC contains the City Population  in millions of people
# - the column nrHosp contains the Number of Hospitals

# %% [markdown]
# # 2 - Select with SQL
#
# With one simple SQL query we can select all the data we need from the cities dataframe.

# %%
large_cities = sqldf("""
SELECT city, popC, nrHosp
FROM cities
WHERE popC > 10.00
""")

large_cities
# Out:
#         city   popC  nrHosp
# 0    Beijing  14.39   551.0
# 1      Delhi  16.75    24.0
# 2    Karachi  14.50    18.0
# 3      Lagos  10.20    11.0
# 4     Moscow  10.56   252.0
# 5     Mumbai  11.98    32.0
# 6  Sao Paulo  11.25   101.0
# 7      Seoul  10.58   223.0
# 8   Shanghai  23.02   296.0
# 9      Tokyo  12.80   658.0

# %% [markdown]
# The SQL command is straightforward.
# - **SELECT city, popC, nrHosp** tels SQL that we want to see the contents of the columns city, popC and nrHosp.
# - **FROM cities** tels SQL from which dataframe the data should be fetched.
# - **WHERE popC > 10.00** tels SQL that we only want data from cities where the population is larger than 10.00 million
#
# The WHERE clause can be made quit complex, e.g.
#
# > WHERE popC > 5.00 AND ppp < 50 AND (train=1 OR metro=1)
#
# would select all cities that have population larger than 5 million, and a ppp smaller than 50000 $ and or a train system, or a metro system or both.

# %%
complex = sqldf("""
SELECT city, popC, ppp, train, metro
FROM cities
WHERE popC > 5.00 AND ppp < 50 AND (train=1 OR metro=1)
""")

complex
# Out:
#         city   popC   ppp  train  metro
# 0    Bangkok   5.72  23.4      1      0
# 1   Istanbul   9.89  22.8      0      1
# 2    Jakarta   9.60   7.2      1      0
# 3      Osaka   8.80  35.2      1      0
# 4  Sao Paulo  11.25  23.7      0      1

# %% [markdown]
# # 3 - Select with pandas
#
# Using standard pandas we could take two steps.
# - first make a new dataframe that only contains the columns city, popC and nrHosp
# - from that new dataframe select the cities with a popC > 10.00.

# %%
selected_cols = cities[['city','popC','nrHosp']]

# %%
large_cities = selected_cols[cities['popC'] > 10.00]
large_cities
# Out:
#          city   popC  nrHosp
# 6     Beijing  14.39   551.0
# 16      Delhi  16.75    24.0
# 33    Karachi  14.50    18.0
# 35      Lagos  10.20    11.0
# 44     Moscow  10.56   252.0
# 45     Mumbai  11.98    32.0
# 54  Sao Paulo  11.25   101.0
# 55      Seoul  10.58   223.0
# 56   Shanghai  23.02   296.0
# 63      Tokyo  12.80   658.0

# %% [markdown]
# True pandas experts might do the same with a one-liner

# %%
cities[['city','popC','nrHosp']][cities['popC'] > 10.00]
# Out:
#          city   popC  nrHosp
# 6     Beijing  14.39   551.0
# 16      Delhi  16.75    24.0
# 33    Karachi  14.50    18.0
# 35      Lagos  10.20    11.0
# 44     Moscow  10.56   252.0
# 45     Mumbai  11.98    32.0
# 54  Sao Paulo  11.25   101.0
# 55      Seoul  10.58   223.0
# 56   Shanghai  23.02   296.0
# 63      Tokyo  12.80   658.0

# %% [markdown]
# Here is the one-liner for our second query

# %%
cities[['city','popC','ppp','train','metro']][ (cities['popC']>5.0) & (cities['ppp']<50) & ((cities['train']==1) | (cities['metro']==1))]
# Out:
#          city   popC   ppp  train  metro
# 4     Bangkok   5.72  23.4      1      0
# 29   Istanbul   9.89  22.8      0      1
# 30    Jakarta   9.60   7.2      1      0
# 47      Osaka   8.80  35.2      1      0
# 54  Sao Paulo  11.25  23.7      0      1

# %% [markdown]
# A more readable way to do the same would be
# - create a list **selected_cols** with all the columns you want to select
# - create a logical filter **selected_rows** to select the rows you need
# - get the result with **dataframe[selected_cols][selected_rows]**

# %%
selected_cols = ['city','popC','ppp','train','metro']
selected_rows = (cities['popC']>5.0) & (cities['ppp']<50) & ((cities['train']==1) | (cities['metro']==1))
cities[selected_cols][selected_rows]
# Out:
#          city   popC   ppp  train  metro
# 4     Bangkok   5.72  23.4      1      0
# 29   Istanbul   9.89  22.8      0      1
# 30    Jakarta   9.60   7.2      1      0
# 47      Osaka   8.80  35.2      1      0
# 54  Sao Paulo  11.25  23.7      0      1

# %% [markdown]
# The pandas version of the second query is clearly more convoluted than the SQL version
# (note more convoluted means harder to write, check and maintain and harder to communicate).

# %% [markdown]
# # 6 - pandas slicing and dicing
#
# You should consider to use pandas when you want to select a number of adjacent rows or columns.
#
# Suppose we only want to see the transportation systems variables.
# The relevant data are in the adjacent columns bikeshare, bus, ... tram.
# We can select these data with a compact command

# %%
trans_syst = cities.loc[:,'bikeshare':'tram']
trans_syst.head()
# Out:
#    bikeshare  bus  ferry  metro  rail  subway  train  tram
# 0          1    1      1      0     1       1      0     0
# 1          0    1      1      1     0       0      0     1
# 2          0    1      0      0     1       1      0     0
# 3          0    1      1      1     0       0      1     1
# 4          1    1      0      0     0       1      1     0

# %% [markdown]
# The **.loc[rowsx,colsx]** functions locates (i.e. selects) the rows specified by rowsx and the columns specified by colsx.
# In our case
# - The : specifies all the rows.
# - The 'bikeshare':'tram' specifies the columns 'bikeshare' up to **and including** 'tram'.
#
# Note that this only works for adjacent columns. If you wanted to add the column city to the above table you can not do
# > cities.loc[:,['city','bikeshare':'tram']]
#
# That gives a syntax error (you can do it but only as demonstrated in section 5)
#
# --------
#
# ### .loc also works well with adjacent rows.
# When we want to select only the rows 10,11,12,13 and 15 we could do that like this

# %%
trans_syst = cities.loc[10:15,'bikeshare':'tram']
trans_syst
# Out:
#     bikeshare  bus  ferry  metro  rail  subway  train  tram
# 10          1    1      0      1     0       0      1     1
# 11          1    1      0      0     1       1      0     0
# 12          0    1      0      0     0       1      0     0
# 13          1    1      0      0     0       1      1     0
# 14          1    1      0      0     1       0      0     1
# 15          1    1      1      1     0       1      1     0

# %% [markdown]
# **NOTE** 10:15 means 10 up to **and including** 15
#
# ## .iloc[] versus .loc[]
#
# The .loc function works with the labels that are found in the index and the column-index.
# There is an other function .iloc that locates by integer (not by label).
#
# For example the bikeshare:tram columns are the columns with number 11,12, ... 18.
# We can do the same selection using the .iloc function
#
# **NOTE** we now need the ranges
# - 10:16 i.e 10 up to **but not including** 16
# - 11:19 i.e 11 up to **but not including** 19

# %%
trans_syst = cities.iloc[10:16,11:19]
trans_syst
# Out:
#     bikeshare  bus  ferry  metro  rail  subway  train  tram
# 10          1    1      0      1     0       0      1     1
# 11          1    1      0      0     1       1      0     0
# 12          0    1      0      0     0       1      0     0
# 13          1    1      0      0     0       1      1     0
# 14          1    1      0      0     1       0      0     1
# 15          1    1      1      1     0       1      1     0

# %% [markdown]
# # 7 - Conclusion
#
# Everything SQL can do, pandas can do (can do in several ways!)
# The pandas way of selecting quickly becomes convoluted and confusing (i.e. something [real programmers](https://xkcd.com/378/) love)

# %% [markdown]
# # Appendix - description of variables in cities.

# %%
codebook = pd.read_excel('./dat/city.xlsx', sheetname='dictionary')
codebook.head(50)
# Out:
#    variable name                                        description  \
# 0           city                           English name of the city
# 1          areaC                                    City Area (km2)
# 2          areaM                                   Metro Area (km2)
# 3           popC                         City Population (millions)
# 4           popM                        Metro Population (millions)
# 5          fornB              Foreign Born (fraction of population)
# 6          growP                Annual Population Growth (fraction)
# 7            ppp                       PPP Per Capita (thousands $)
# 8          share           Share of Global 500 Companies (fraction)
# 9         unempR                       Unemployment Rate (fraction)
# 10        poverR                            Poverty Rate (fraction)
# 11     bikeshare                  has transportation type bikeshare
# 12           bus                        has transportation type bus
# 13         ferry                      has transportation type ferry
# 14         metro                      has transportation type metro
# 15          rail                       has transportation type rail
# 16        subway                     has transportation type subway
# 17         train                      has transportation type train
# 18          tram                       has transportation type tram
# 19         mtCom                  Mass Transit Commuters (fraction)
# 20        airPrt                          number of Major Airports)
# 21         ports                              number of Major ports
# 22        studHE              Students Enrolled in Higher Education
# 23        percHE  Percent/fraction of Population with Higher Edu...
# 24        instHE            number of Higher Education Institutions
# 25       totTour                 Total Tourists Annually (millions)
# 26       forTour               Foreign Tourists Annually (millions)
# 27       domTour              Domestic Tourists Annually (millions)
# 28       annTour              Annual Tourism Revenue ($US billions)
# 29       hotRoom                            Hotel Rooms (thousands)
# 30        infMrt         Infant Mortality (Deaths per 1,000 Births)
# 31        lfExpM                    Life Expectancy in Years (Male)
# 32        lfExpF                  Life Expectancy in Years (Female)
# 33         nrMDs                      Physicians per 100,000 People
# 34        nrHosp                                Number of Hospitals
# 35        asLegi                           Anti-Smoking Legislation
# 36         nrMus                                  Number of Museums
# 37        nrArts          Number of Cultural and Arts Organizations
# 38        greens               fraction Green Spaces of total space
# 39          airQ                            Air Quality (ppm? PM10)
# 40        effLaw   Laws or Regulations to Improve Energy Efficiency
# 41        retFit                     Retrofitted City Vehicle Fleet
#
#     variable group       domain type                 domain constraint  \
# 0              NaN            string  identifier (unique and not null)
# 1        Geography              real               >=0 with 0 decimals
# 2        Geography              real               >=0 with 0 decimals
# 3           People              real              >=0 up to 2 decimals
# 4           People              real              >=0 up to 2 decimals
# 5           People              real   >= 0 and <= 1, up to 3 decimals
# 6           People              real   >= 0 and <= 1, up to 3 decimals
# 7          Economy              real              >=0, up to 1 decimal
# 8          Economy              real   >= 0 and <= 1, up to 3 decimals
# 9          Economy              real   >= 0 and <= 1, up to 3 decimals
# 10         Economy              real   >= 0 and <= 1, up to 3 decimals
# 11  Transportation  boolean (0 or 1)                            0 or 1
# 12  Transportation  boolean (0 or 1)                            0 or 1
# 13  Transportation  boolean (0 or 1)                            0 or 1
# 14  Transportation  boolean (0 or 1)                            0 or 1
# 15  Transportation  boolean (0 or 1)                            0 or 1
# 16  Transportation  boolean (0 or 1)                            0 or 1
# 17  Transportation  boolean (0 or 1)                            0 or 1
# 18  Transportation  boolean (0 or 1)                            0 or 1
# 19  Transportation              real   >= 0 and <= 1, up to 2 decimals
# 20  Transportation    natural number                              >= 0
# 21  Transportation    natural number                              >= 0
# 22       Education              real              >= 0 with 0 decimals
# 23       Education              real     >= 0 and <= 1 with 2 decimals
# 24       Education    natural number                              >= 0
# 25         Tourism              real               >=0 up to 2 decimal
# 26         Tourism              real               >=0 up to 2 decimal
# 27         Tourism              real               >=0 up to 2 decimal
# 28         Tourism              real               >=0 up to 2 decimal
# 29         Tourism              real               >=0 up to 2 decimal
# 30          Health              real               >=0 up to 2 decimal
# 31          Health    natural number                               >=0
# 32          Health    natural number                               >=0
# 33          Health              real               >=0 up to 0 decimal
# 34          Health    natural number                               >=0
# 35          Health  boolean (0 or 1)                            0 or 1
# 36         Culture    natural number                               >=0
# 37         Culture    natural number                               >=0
# 38     Environment              real      >=0 ad <=1, up to 2 decimals
# 39     Environment              real      >=0 ad <=1, up to 2 decimals
# 40     Environment           boolean                  boolean (0 or 1)
# 41     Environment           boolean                  boolean (0 or 1)
#
#                       measurement unit missing values
# 0                                  NaN    not allowed
# 1                                 km^2     empty cell
# 2                                 km^2     empty cell
# 3                 in milions of people     empty cell
# 4                 in milions of people     empty cell
# 5                                  NaN     empty cell
# 6                                  NaN     empty cell
# 7               in kilo-$ of year ????     empty cell
# 8                                  NaN     empty cell
# 9                                  NaN     empty cell
# 10                                 NaN     empty cell
# 11                                 NaN    not allowed
# 12                                 NaN    not allowed
# 13                                 NaN    not allowed
# 14                                 NaN    not allowed
# 15                                 NaN    not allowed
# 16                                 NaN    not allowed
# 17                                 NaN    not allowed
# 18                                 NaN    not allowed
# 19                                 NaN     empty cell
# 20                  number of airports     empty cell
# 21                     number of ports     empty cell
# 22                  number of students     empty cell
# 23                                 NaN     empty cell
# 24       Higher Education Institutions     empty cell
# 25        milions of Tourists per year     empty cell
# 26        milions of Tourists per year     empty cell
# 27        milions of Tourists per year     empty cell
# 28         milions of US $ of year????     empty cell
# 29         in thousands of Hotel Rooms     empty cell
# 30             Deaths per 1,000 Births     empty cell
# 31                               years     empty cell
# 32                               years     empty cell
# 33       Physicians per 100,000 People     empty cell
# 34                     nr of Hospitals     empty cell
# 35                                 NaN     empty cell
# 36                          in Museums     empty cell
# 37  in Cultural and Arts Organizations     empty cell
# 38                                 NaN     empty cell
# 39                                 NaN     empty cell
# 40                                 NaN     empty cell
# 41                                 NaN     empty cell
